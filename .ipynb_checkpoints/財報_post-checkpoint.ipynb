# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import bs4

# %%
pr = 'https://mops.twse.com.tw/mops/web/t164sb04'#綜合損益表
bs = 'https://mops.twse.com.tw/mops/web/t164sb03'#資產負債表

# %%
stock_number =3293
year = 108
season = 4

form_data = {
        'encodeURIComponent':1,
        'step':1,
        'firstin':1,
        'off':1,
        'co_id':stock_number,
        'year': year,
        'season': season,}

r = requests.post(bs,form_data)
df = pd.read_html(r.text)

# %%
newdf = df[10]
#newdf.columns[0]='項目'
c = list(newdf.columns)
c[0]='項目'
newdf.columns=c

# %%
newdf = newdf.drop(columns=[newdf.columns[5],newdf.columns[6]])

# %%
newdf[newdf.項目=='合約負債－流動']
# Out:
#          項目  (民國108年第4季, 單位：新台幣仟元, 108年12月31日, 金額)  \
# 21  合約負債－流動                               188013.0
#
#     (民國108年第4季, 單位：新台幣仟元, 108年12月31日, %)  \
# 21                                  2.83
#
#     (民國108年第4季, 單位：新台幣仟元, 107年12月31日, 金額)  \
# 21                               152226.0
#
#     (民國108年第4季, 單位：新台幣仟元, 107年12月31日, %)
# 21                                   3.3

# %%
pd.read_html('https://doc.twse.com.tw/server-java/t57sb01?step=1&colorchg=1&co_id=5515&year=107&seamon=&mtype=A&')[1]
# Out:
#    證券代號       資料年度   資料類型  結案類型  性質         資料細節說明  備註                 電子檔案  \
# 0  5515  107 年 第一季  財務報告書   NaN NaN      IFRSs合併財報 NaN  201801_5515_AI1.pdf
# 1  5515  107 年 第二季  財務報告書   NaN NaN      IFRSs合併財報 NaN  201802_5515_AI1.pdf
# 2  5515  107 年 第三季  財務報告書   NaN NaN      IFRSs合併財報 NaN  201803_5515_AI1.pdf
# 3  5515  107 年 第四季  財務報告書   NaN NaN      IFRSs合併財報 NaN  201804_5515_AI1.pdf
# 4  5515  107 年 第四季  財務報告書   NaN NaN      IFRSs個體財報 NaN  201804_5515_AI3.pdf
# 5  5515  107 年 第四季  財務報告書   NaN NaN  IFRSs英文版-合併財報 NaN  201804_5515_AIA.pdf
# 6  5515  107 年 第四季  財務報告書   NaN NaN  IFRSs英文版-個體財報 NaN  201804_5515_AIC.pdf
#
#       檔案大小                上傳日期 財務報告更(補)正
# 0  5841429  107/05/14 18:24:35         無
# 1  6108461  107/08/14 15:48:43         無
# 2  8373698  107/11/13 18:24:28         無
# 3  8109897  108/03/29 15:49:34         無
# 4  6690568  108/03/29 15:50:45         無
# 5  2822908  108/05/21 12:28:02         無
# 6  2183740  108/05/21 12:28:48         無

# %%
dfs = pd.read_html(r.text, header=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-3b7890e7b27a> in <module>
# ----> 1 dfs = pd.read_html(r.text, header=None)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     911     else:
#     912         assert retained is not None  # for mypy
# --> 913         raise retained
#     914
#     915     ret = []
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     891
#     892         try:
# --> 893             tables = p.parse_tables()
#     894         except ValueError as caught:
#     895             # if `io` is an io-like object, check if it's seekable
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in parse_tables(self)
#     211         list of parsed (header, body, footer) tuples from tables.
#     212         """
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/html.py in _parse_tables(self, doc, match, attrs)
#     541
#     542         if not tables:
# --> 543             raise ValueError("No tables found")
#     544
#     545         result = []
#
# ValueError: No tables found

# %%
import requests , bs4

# %%
html = requests.get('https://movies.yahoo.com.tw/')

# %%
soup = bs4.BeautifulSoup(html.text,'html.parser')

# %%
html.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh_TW">\n<head>\n  <meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1, user-minimum-scale=1, maximum-scale=1">\n  <meta http-equiv="content-type" content="text/html; charset=utf-8">\n  <meta property="fb:app_id" content="501887343352051">\n  <meta property="og:site_name" content="Yahoo奇摩電影">\n    <title>Yahoo奇摩電影</title>\n<meta name="twitter:title" content="Yahoo奇摩電影">\n  <meta property="og:title" content="Yahoo奇摩電影">\n\n<link rel="canonical" href="https://movies.yahoo.com.tw">\n<meta property="og:url" content="https://movies.yahoo.com.tw">\n\n<meta name="twitter:description" content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態">\n<meta name="description" content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態">\n\n  <meta property="og:description" content="提供最新的電影資訊、預告片、劇照、電影時刻表、明星資訊、網友期待榜、網友滿意榜、票房榜和電影相關動態">\n\n<meta name="twitter:image" content="https://movies.yahoo.com.tw/build/images/ogImage.png">\
# ...

# %%
num = soup.select('ul.ranking_list_r li div.num')
rank = soup.select('ul.ranking_list_r li span')

# %%
for i in rank:
    print(i.text)
# Out:
# 當男人戀愛時
# 名偵探柯南 緋色的彈丸
# 永生戰
# 聽見歌 再唱
# 哥吉拉大戰金剛
# 真人快打
# 鐵幕行動
# 無名弒
# 劇場版 假面騎士ZERO-ONE REAL×TIME+劇場短篇 假面騎士聖刃 不死鳥的劍士與破滅
# 夢想之地
# 哥吉拉大戰金剛
# 無名弒
# The Unholy
# 尋龍使者：拉雅
# 湯姆貓與傑利鼠
# 一級任務
# The Girl Who Believes in Miracles
# In the Earth
# 鐵幕行動
# 古魯家族：新石代
# 聽見歌 再唱
# 永生戰
# 名偵探柯南：緋色的彈丸
# 父親
# 藥命交錯
# 玩命鈔劫
# 真‧三國無雙
# 惡夜殺神
# 樹海村
# 不日成婚

# %%
print(num)
# Out:
# [<div class="num">10</div>]

# %%
items = soup.find_all('div','r_box _c')[0].find_all('li')

# %%
for i in items:
    name = i.span
    print(name)
# Out:
# None
# None
# None
# <span>當男人戀愛時</span>
# <span>名偵探柯南 緋色的彈丸</span>
# <span>永生戰</span>
# <span>聽見歌 再唱</span>
# <span>哥吉拉大戰金剛</span>
# <span>真人快打</span>
# <span>鐵幕行動</span>
# <span>無名弒</span>
# <span>劇場版 假面騎士ZERO-ONE REAL×TIME+劇場短篇 假面騎士聖刃 不死鳥的劍士與破滅</span>
# <span>夢想之地</span>
# <span>哥吉拉大戰金剛</span>
# <span>無名弒</span>
# <span>The Unholy</span>
# <span>尋龍使者：拉雅</span>
# <span>湯姆貓與傑利鼠</span>
# <span>一級任務</span>
# <span>The Girl Who Believes in Miracles</span>
# <span>In the Earth</span>
# <span>鐵幕行動</span>
# <span>古魯家族：新石代</span>
# <span>聽見歌 再唱</span>
# <span>永生戰</span>
# <span>名偵探柯南：緋色的彈丸</span>
# <span>父親</span>
# <span>藥命交錯</span>
# <span>玩命鈔劫</span>
# <span>真‧三國無雙</span>
# <span>惡夜殺神</span>
# <span>樹海村</span>
# <span>不日成婚</span>

# %%
items.select('div')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-e0ffaa8fb965> in <module>
# ----> 1 items.select('div')
#
# /opt/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2172         """Raise a helpful exception to explain a common code fix."""
#    2173         raise AttributeError(
# -> 2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'select'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
num
# Out:
# <div class="num">10</div>

# %%
items[4].span.text
# Out:
# '名偵探柯南 緋色的彈丸'

# %%
items[0].find_all('li')
# Out:
# [<li class="select" data-id="list1">台北票房榜</li>,
#  <li data-id="list2">全美票房榜</li>,
#  <li data-id="list3">預告片榜</li>,
#  <li class="select">
#  <div class="num">1</div>
#  <span>當男人戀愛時</span>
#  </li>,
#  <li class="">
#  <div class="num">2</div>
#  <span>名偵探柯南 緋色的彈丸</span>
#  </li>,
#  <li class="">
#  <div class="num">3</div>
#  <span>永生戰</span>
#  </li>,
#  <li class="">
#  <div class="num">4</div>
#  <span>聽見歌 再唱</span>
#  </li>,
#  <li class="">
#  <div class="num">5</div>
#  <span>哥吉拉大戰金剛</span>
#  </li>,
#  <li class="">
#  <div class="num">6</div>
#  <span>真人快打</span>
#  </li>,
#  <li class="">
#  <div class="num">7</div>
#  <span>鐵幕行動</span>
#  </li>,
#  <li class="">
#  <div class="num">8</div>
#  <span>無名弒</span>
#  </li>,
#  <li class="unclick">
#  <div class="num">9</div>
#  <span>劇場版 假面騎士ZERO-ONE REAL×TIME+劇場短篇 假面騎士聖刃 不死鳥的劍士與破滅</span>
#  </li>,
#  <li class="">
#  <div class="num">10</div>
#  <span>夢想之地</span>
#  </li>,
#  <li class="select">
#  <div class="num">1</div>
# ...

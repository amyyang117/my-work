# %%
import numpy as np
import pandas as pd
import requests 
from bs4 import BeautifulSoup

# %%
web = requests.get('https://docs.google.com/forms/d/e/1FAIpQLSfOzVrNmp60rd4OjvZFUNIyFLpQjTMoMUasu7M4XrX_DU0HfQ/viewform')

# %%
soup = BeautifulSoup(web.text)

# %%
question = soup.select('div',{'aria-level':"3"})

# %%
for i in question:
    print(i.text)
# Out:
# AppWorks School Batch #14 ApplicationAppWorks School aims to provide the most practical and up-to-date training for aspiring software engineers. In AppWorks School Batch #14, AppWorks School is opening following classes for you to join:- Android Class- iOS Class- Front-End Class- Back-End Class- Data Engineering ClassThe program is entirely free of charge. However, due to capacity constraints, we can only accommodate 15 members for Android Class, 15 members for iOS Class, 15 members for Front-End Class and 15 members for Backend Class, 5 members for Data Engineering ClassFor Data Engineering Class, the applicants need to have basic understanding of matrix computation, trigonometric functions, vector.If you didn't have any programming experience before, the following online materials are the first learning assignment of our remote courses. We highly recommend you spend 2-3 hours around these materials to get to know how you feel while learning to code.Android: http://shop.oreilly.com/
# ...

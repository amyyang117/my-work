# %%
import pandas as pd
import numpy as np

# %%
currency = pd.read_html("https://www.taifex.com.tw/cht/3/dailyFXRate")

# %% [markdown]
# ## 知道我要取得是哪個資料

# %%
item = 0
for c in currency:
    print("元素",item)
    print(c)
    print()
    item+=1
# Out:
# 元素 0
#                          每日外幣參考匯率查詢
# 0  日期(起)：  選擇日期(起)  日期(迄)：  選擇日期(迄)
#
# 元素 1
#         0        1
# 0  日期(起)：  選擇日期(起)
# 1  日期(迄)：  選擇日期(迄)
#
# 元素 2
#             日期  美元／新台幣   人民幣／新台幣    歐元／美元    美元／日幣    英鎊／美元    澳幣／美元    美元／港幣  \
# 0   2021/03/02  28.319  4.373190  1.20105  106.835  1.38855  0.77520  7.75855
# 1   2021/03/03  28.258  4.372134  1.20835  106.835  1.39745  0.78270  7.75625
# 2   2021/03/04  28.266  4.366192  1.20480  107.165  1.39545  0.78010  7.75815
# 3   2021/03/05  28.276  4.359452  1.19330  108.305  1.38575  0.76885  7.76165
# 4   2021/03/08  28.303  4.329425  1.18920  108.405  1.38385  0.76780  7.76695
# 5   2021/03/09  28.390  4.345970  1.18800  108.915  1.38605  0.76765  7.76680
# 6   2021/03/10  28.326  4.347843  1.18785  108.795  1.38790  0.76870  7.76345
# 7   2021/03/11  28.241  4.345782  1.19410  108.675  1.39405  0.77725  7.75865
# 8   2021/03/12  28.187  4.331243  1.19420  109.065  1.39485  0.77505  7.76290
# ...

# %%
currency[2]
# Out:
#             日期  美元／新台幣   人民幣／新台幣    歐元／美元    美元／日幣    英鎊／美元    澳幣／美元    美元／港幣  \
# 0   2021/03/02  28.319  4.373190  1.20105  106.835  1.38855  0.77520  7.75855
# 1   2021/03/03  28.258  4.372134  1.20835  106.835  1.39745  0.78270  7.75625
# 2   2021/03/04  28.266  4.366192  1.20480  107.165  1.39545  0.78010  7.75815
# 3   2021/03/05  28.276  4.359452  1.19330  108.305  1.38575  0.76885  7.76165
# 4   2021/03/08  28.303  4.329425  1.18920  108.405  1.38385  0.76780  7.76695
# 5   2021/03/09  28.390  4.345970  1.18800  108.915  1.38605  0.76765  7.76680
# 6   2021/03/10  28.326  4.347843  1.18785  108.795  1.38790  0.76870  7.76345
# 7   2021/03/11  28.241  4.345782  1.19410  108.675  1.39405  0.77725  7.75865
# 8   2021/03/12  28.187  4.331243  1.19420  109.065  1.39485  0.77505  7.76290
# 9   2021/03/15  28.243  4.342502  1.19320  109.115  1.39330  0.77470  7.76455
# 10  2021/03/16  28.263  4.347415  1.19250  109.215  1.38315  0.77235  7.76555
# ...
